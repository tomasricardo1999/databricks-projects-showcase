# %%
text = "Hello World"
print(text)

# %%
# %sql
select "Hello" as text

# %%
display(dbutils.fs.ls("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/"))

display(dbutils.fs.ls("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/magnificent7stocks-etl/04_tables/"))

display(dbutils.fs.head("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/magnificent7stocks-etl/04_tables/01_bronze_layer_historical.csv"))

dbutils.fs.cp("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/magnificent7stocks-etl/04_tables/01_bronze_layer_historical.csv","dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/")

display(dbutils.fs.ls("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/"))

dbutils.fs.rm("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/01_bronze_layer_historical.csv")

# %%
dbutils.fs.rm("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/01_bronze_layer_historical.csv")

# %%
dbutils.fs.cp("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/magnificent7stocks-etl/","dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/",recurse=True)

# %%
display(dbutils.fs.ls("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/"))

# %%
dbutils.fs.rm("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/01_notebooks/",recurse=True)
dbutils.fs.rm("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/02_config",recurse=True)
dbutils.fs.rm("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/03_jobs/",recurse=True)
dbutils.fs.rm("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/04_tables/",recurse=True)
dbutils.fs.rm("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/05_pipelines/",recurse=True)
dbutils.fs.rm("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/06_Dashboards/",recurse=True)
dbutils.fs.rm("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/07_logos/",recurse=True)
dbutils.fs.rm("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/01_bronze_layer_historical.csv",recurse=True)
dbutils.fs.rm("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/PySpark-Showcase_Learning_Sandbox/01_bronze_layer_snapshot.csv",recurse=True)

# %%
df = spark.read.format("csv").option("header", "true").load("dbfs:/Workspace/Users/tomasricardo1999@gmail.com/databricks-projects-showcase/magnificent7stocks-etl/04_tables/01_bronze_layer_historical.csv")
display(df)

# %%
df.write.format("delta").mode("overwrite").saveAsTable("workspace.pyspark_sandbox.teste")

# %%
data = [['John',21],['Mary',22],['James',23]]
type(data)

# %%
display(spark.createDataFrame(data))

df = spark.createDataFrame(data)

df.show()

df.write.format("delta").mode("overwrite").saveAsTable("workspace.pyspark_sandbox.teste2")

# %%
display(spark.sql("select * from workspace.pyspark_sandbox.teste2"))

# %%
# %sql
select * from workspace.pyspark_sandbox.teste2

# %%
schema = "name string, age int"
df = spark.createDataFrame(data,schema)
df.show()
display(df)

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
from pyspark.sql.functions import col

# %%
schema = StructType (

    [
     StructField("name",StringType(), True),
     StructField("age", IntegerType(), True)
     ]

)

# %%
df = spark.createDataFrame(data,schema)
df.show()
display(df)

# %%
df.schema

df.dtypes

df.printSchema()

df.describe()

# %%
df.filter('age > 22')
display(df.filter('age > 22'))

df.filter(col("age")> 21)
display(df.filter(col("age")> 21))

# %%
df.filter("age > 21").write.format("delta").mode("overwrite").saveAsTable("workspace.pyspark_sandbox.teste3")

# %%
from pyspark.sql.types import StructType, StructField, StringType, LongType, IntegerType

# Define the schema explicitly using StructType and StructField
schema = StructType([
    StructField("country_name", StringType(), True),
    StructField("continent", StringType(), True),
    StructField("population", LongType(), True),
    StructField("area_km2", IntegerType(), True)
])

# Extended data for countries (country_name, continent, population, area_km2)
data = [
    ("Afghanistan", "Asia", 38928346, 652230),
    ("Albania", "Europe", 2877797, 28748),
    ("Algeria", "Africa", 43851044, 2381741),
    ("Andorra", "Europe", 77265, 468),
    ("Angola", "Africa", 32866272, 1246700),
    ("Antigua and Barbuda", "North America", 97929, 442),
    ("Argentina", "South America", 45376763, 2780400),
    ("Armenia", "Asia", 2963243, 29743),
    ("Australia", "Oceania", 25649984, 7692024),
    ("Austria", "Europe", 9006398, 83879),
    ("Azerbaijan", "Asia", 10139177, 86600),
    ("Bahamas", "North America", 393244, 13943),
    ("Bahrain", "Asia", 1701575, 765),
    ("Bangladesh", "Asia", 166988339, 147570),
    ("Barbados", "North America", 287375, 430),
    ("Belarus", "Europe", 9449323, 207600),
    ("Belgium", "Europe", 11589623, 30528),
    ("Belize", "North America", 397628, 22966),
    ("Benin", "Africa", 12123200, 112622),
    ("Bhutan", "Asia", 771608, 38394),
    ("Bolivia", "South America", 11673021, 1098581),
    ("Bosnia and Herzegovina", "Europe", 3280819, 51197),
    ("Botswana", "Africa", 2351625, 581730),
    ("Brazil", "South America", 212559417, 8515767),
    ("Brunei", "Asia", 437479, 5765),
    ("Bulgaria", "Europe", 6948445, 110879),
    ("Burkina Faso", "Africa", 20903273, 274222),
    ("Burundi", "Africa", 11890784, 27834),
    ("Cambodia", "Asia", 16718965, 181035),
    ("Cameroon", "Africa", 26545863, 475442),
    ("Canada", "North America", 38005238, 9984670),
    ("Chile", "South America", 19116201, 756102),
    ("China", "Asia", 1444216107, 9596961),
    ("Colombia", "South America", 50882891, 1141748),
    ("Costa Rica", "North America", 5094118, 51100),
    ("Croatia", "Europe", 4105267, 56594),
    ("Cuba", "North America", 11326616, 109884),
    ("Czech Republic", "Europe", 10708981, 78865),
    ("Denmark", "Europe", 5831404, 43094),
    ("Dominican Republic", "North America", 10847904, 48671),
    ("Ecuador", "South America", 17643054, 283561),
    ("Egypt", "Africa", 102334404, 1010408),
    ("Estonia", "Europe", 1326535, 45227),
    ("Ethiopia", "Africa", 114963588, 1104300),
    ("Finland", "Europe", 5540720, 338424),
    ("France", "Europe", 65273511, 551695),
    ("Germany", "Europe", 83783942, 357022),
    ("Ghana", "Africa", 31072940, 238533),
    ("Greece", "Europe", 10423054, 131957),
    ("Hungary", "Europe", 9660351, 93028),
    ("India", "Asia", 1393409038, 3287263),
    ("Indonesia", "Asia", 273523615, 1904569),
    ("Iran", "Asia", 83992949, 1648195),
    ("Iraq", "Asia", 40222493, 438317),
    ("Ireland", "Europe", 4937786, 70273),
    ("Israel", "Asia", 8655535, 20770),
    ("Italy", "Europe", 60461826, 301340),
    ("Japan", "Asia", 126476461, 377975),
    ("Kenya", "Africa", 53771296, 580367),
    ("Malaysia", "Asia", 32365999, 330803),
    ("Mexico", "North America", 128932753, 1964375),
    ("Morocco", "Africa", 36910560, 446550),
    ("Netherlands", "Europe", 17134872, 41543),
    ("New Zealand", "Oceania", 4822233, 268838),
    ("Nigeria", "Africa", 206139589, 923768),
    ("Norway", "Europe", 5421241, 385207),
    ("Pakistan", "Asia", 220892340, 881912),
    ("Peru", "South America", 32971854, 1285216),
    ("Philippines", "Asia", 109581078, 300000),
    ("Poland", "Europe", 37846611, 312696),
    ("Portugal", "Europe", 10196709, 92212),
    ("Romania", "Europe", 19237691, 238397),
    ("Russia", "Europe", 145934462, 17098242),
    ("Saudi Arabia", "Asia", 34813871, 2149690),
    ("Serbia", "Europe", 8737371, 88361),
    ("Singapore", "Asia", 5850342, 728),
    ("South Africa", "Africa", 59308690, 1221037),
    ("South Korea", "Asia", 51269185, 100210),
    ("Spain", "Europe", 46754778, 505990),
    ("Sweden", "Europe", 10099265, 450295),
    ("Switzerland", "Europe", 8654622, 41284),
    ("Thailand", "Asia", 69799978, 513120),
    ("Turkey", "Europe", 84339067, 783356),
    ("Ukraine", "Europe", 43733762, 603500),
    ("United Arab Emirates", "Asia", 9890402, 83600),
    ("United Kingdom", "Europe", 67886011, 243610),
    ("United States", "North America", 331002651, 9833517),
    ("Uruguay", "South America", 3473730, 176215),
    ("Vietnam", "Asia", 97338579, 331212),
    ("Zambia", "Africa", 18383955, 752618),
    ("Zimbabwe", "Africa", 14862924, 390757)
]

# %%
df = spark.createDataFrame(data,schema)
display(df.orderBy(col("population").desc()).limit(40))
# Out:
# Databricks visualization. Run in Databricks to view.
